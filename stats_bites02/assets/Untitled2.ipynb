# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# set random seed for reproducibility
np.random.seed(123)

# generate random data for two variables with a correlation of 0.95
mean = [0, 0]
cov = [[1, 0.77], [0.77, 0.9]]
data = np.random.multivariate_normal(mean, cov, 50)

# create the dataframe
df = pd.DataFrame(data, columns=['Var1', 'Var2'])

# %%
x = df["Var1"]
y = df["Var2"]
m, c = np.polyfit(x, y, 1)
# Plot the line of best fit
plt.scatter(x, y)
#plt.plot(x, m*x+c, color='green')

# Add labels and a title
plt.xlabel('x')
plt.ylabel('y')
plt.axis('off')

plt.title('95% positive correlation')


# Show the plot
plt.show()

# %%
df
# Out:
#         Var1      Var2
# 0   0.751328  1.281418
# 1   0.164109 -0.718093
# 2   0.076997  1.028063
# 3   2.447145  2.045125
# 4  -0.961670 -1.402946
# 5   0.677310  0.579934
# 6  -1.243318 -1.535018
# 7   0.550507  0.264503
# 8  -2.743490 -1.305338
# 9  -1.072802 -0.781862
# 10 -1.136482 -0.202195
# 11  0.556367  1.202018
# 12  1.384637  0.928491
# 13 -0.455837 -1.254163
# 14  0.382981 -0.139892
# 15  1.052981 -0.633089
# 16  1.898173  1.373801
# 17 -0.837793 -0.885661
# 18 -0.201489  0.209536
# 19  0.760143  0.876557
# 20  1.270012  0.190188
# 21  0.208523  0.527559
# 22 -0.320744 -0.307440
# 23 -2.409672 -2.019268
# 24 -1.583422 -0.188429
# 25  1.538951  0.840976
# 26 -1.438921 -1.810459
# 27 -0.337245  0.302898
# 28 -1.359575 -0.258371
# 29 -1.740759 -1.012391
# 30  0.510219  0.938254
# 31  0.082156 -0.690691
# 32 -1.590040 -1.022885
# 33  0.023767 -0.112647
# 34  1.089614  1.136646
# 35 -0.208434 -0.676437
# 36 -0.795799 -1.380895
# 37  1.732348  2.225333
# 38  0.422576  0.323076
# 39  1.265642  0.256541
# 40 -1.002798 -1.338532
# 41 -1.823331 -1.241478
# 42  0.614962 -0.052230
# 43  1.051436  0.283528
# 44 -2.045667 -1.821956
# 45 -0.735171 -1.422565
# 46 -0.513496  0.200550
# 47  0.022941  0.618342
# 48  1.432132  0.552932
# 49 -0.253724 -0.457262
